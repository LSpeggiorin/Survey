# %% [markdown]
# # Pubmed

# %%
#!pip install pymed

# %%
from pymed import PubMed

# %%
pubmed = PubMed(tool="MyTool", email="my@email.address")

# %%
q_pubmed = '( "graph" OR "community detection " OR "group" OR "cluster") AND ( "relevance" OR "redundancy" ) AND ( "feature selection" OR "dimensionality reduction" ) AND ( "biological" OR "Gene expression" OR "omics" )'

q_pubmed
# Out:
# '( "graph" OR "community detection " OR "group" OR "cluster") AND ( "relevance" OR "redundancy" ) AND ( "feature selection" OR "dimensionality reduction" ) AND ( "biological" OR "Gene expression" OR "omics" )'

# %%
results = list(pubmed.query(q_pubmed, max_results=500))
len(results)
# Out:
# 116

# %%
pubmed_results = []

for article in results:

    # Extract and format information from the article
    article_id = article.pubmed_id
    title = article.title
    if article.keywords:
        if None in article.keywords:
            article.keywords.remove(None)
        keywords = '", "'.join(article.keywords)
    publication_date = article.publication_date
    abstract = article.abstract

    pubmed_results.append(
        {
            "ID":article_id, 
            "Title":title, 
            "Abstract":abstract, 
            "Keywords":keywords, 
            "Publication date":publication_date
        }
    )


    # Show information about the article
    #print(
    #    f'{publication_date} - {title}\nKeywords: "{keywords}"\n'
    #)

print(len(pubmed_results))
# Out:
# 116

# %%
import pandas as pd

pubmed_results = pd.DataFrame(pubmed_results)
pubmed_results.head()
# Out:
#                                                   ID  \
# 0  41568381\n21965334\n25114853\n30591591\n399792...
# 1                                           41518988
# 2  41387731\n36137835\n36416120\n38216661\n373753...
# 3  41331264\n16963055\n38264914\n32593128\n381857...
# 4  41301201\n33974890\n30785707\n35779479\n348391...
#
#                                                Title  \
# 0  Integrative multi-omics stratification and tra...
# 1  Knowledge graph integration of clustered medic...
# 2  Feature learning augmented with sampling and h...
# 3  Machine learning-based prediction of drug resp...
# 4  A Multi-Task Ensemble Strategy for Gene Select...
#
#                                             Abstract  \
# 0  Immunosuppressive breast cancer subtypes drive...
# 1  This study builds on the premise that phytoche...
# 2  Big biological datasets, such as gene expressi...
# 3  Myocardial ischemia is a major global contribu...
# 4  Gene expression-based tumor classification aim...
#
#                                             Keywords Publication date
# 0  breast cancer", "immunosuppressive tumormicroe...       2026-01-22
# 1  AI-based therapeutic mapping", "Chemical space...       2026-01-11
# 2  AI-based therapeutic mapping", "Chemical space...       2025-12-13
# 3  Anti-inflammatory therapy", "Cardioprotection"...       2025-12-03
# 4  gene expression-based tumor classification", "...       2025-11-27

# %%
pubmed_results.to_csv("PubmedArticles.csv")

# %% [markdown]
# # Scopus

# %%
#!pip install pybliometrics

# %%
import pybliometrics
from pybliometrics.scopus import ScopusSearch

# %%
import os
os.environ['PYBLIOMETRICS_API_KEY'] = 'ab528db237c9103c9e4cee942f602c28' # Substitua 'YOUR_API_KEY' pela sua chave de API Scopus real.
pybliometrics.scopus.init()

# %%
q_scopus = 'TITLE-ABS-KEY ( ( "graph" OR "community detection " OR "group" OR "cluster") AND ( "relevance" OR "redundancy" ) AND ( "feature selection" OR "dimensionality reduction" ) AND ( "biological" OR "Gene expression" OR "omics" ) )'

# %%
s = ScopusSearch(q_scopus, verbose=True)

print(len(s.results))
# Out:
# 303

# %%
import pandas as pd

scopus_results = pd.DataFrame(s.results)

scopus_results.head()
# Out:
#                    eid                                 doi                pii  \
# 0  2-s2.0-105027408346          10.1007/s12559-025-10544-9                NaN
# 1  2-s2.0-105027299893          10.1007/s10238-025-01866-x                NaN
# 2  2-s2.0-105022078059          10.1007/s10238-025-01894-7                NaN
# 3  2-s2.0-105027426803           10.1016/j.gep.2026.119406  S1567133X26000013
# 4  2-s2.0-105027398275  10.1016/j.compbiolchem.2026.108895  S1476927126000204
#
#   pubmed_id                                              title subtype  \
# 0       NaN  Leveraging Segmentation and Visibility Graph A...      ar
# 1  41348242  Integrating multi-omics data to resolve patter...      ar
# 2  41249578  Single-cell transcriptomics identifies SOCS3+ ...      ar
# 3  41520694  Exploring NPM1P51 as a key biomarker for glauc...      ar
# 4  41518988  Knowledge graph integration of clustered medic...      ar
#
#   subtypeDescription       creator                          afid  \
# 0            Article  Mohammady F.             60003666;60033391
# 1            Article       Xing J.             60069744;60073448
# 2            Article      Jiang X.            60025234;133403086
# 3            Article    Vaishnavi             60076774;133643050
# 4            Article   Shajil U.K.  60013170;129854699;133643214
#
#                                            affilname  ... pageRange  \
# 0  University of Mazandaran;Shahrood University o...  ...       NaN
# 1  General Hospital of People's Liberation Army;P...  ...       NaN
# 2  Naval Medical University;Yingtan Municipal Peo...  ...       NaN
# 3  Amity University;BioinfoCore Solutions (OPC) P...  ...       NaN
# 4  National Institute of Technology Calicut;UL Re...  ...       NaN
#
#                                          description  \
# 0  Motor Imagery Brain-Computer Interfaces (MI-BC...
# 1  Skin cutaneous melanoma (SKCM) represents a hi...
# 2  Clear cell renal cell carcinoma (ccRCC), a pre...
# 3  Glaucoma is a group of optic neuropathic condi...
# 4  This study builds on the premise that phytoche...
#
#                                         authkeywords citedby_count openaccess  \
# 0  Brain computer interface | Electroencephalogra...             0          1
# 1  Ion channel genes | Melanoma | Multi-omics | P...             0          1
# 2  Biomarker | Exhausted T cell | Renal cell carc...             0          1
# 3  Artificial neural network (ANN) and biomarkers...             0          0
# 4  AI-based therapeutic mapping | Chemical space ...             0          0
#
#                                         freetoread  \
# 0                          all publisherhybridgold
# 1  all publisherhybridgold repository repositoryam
# 2  all publisherhybridgold repository repositoryam
# 3                                              NaN
# 4                                              NaN
#
#                      freetoreadLabel fund_acr fund_no  \
# 0        All Open Access Hybrid Gold      NaN     NaN
# 1  All Open Access Hybrid Gold Green      NaN     NaN
# 2  All Open Access Hybrid Gold Green      NaN     NaN
# 3                                NaN      NaN     NaN
# 4                                NaN     NITC     NaN
#
#                                fund_sponsor
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  National Institute of Technology Calicut
#
# [5 rows x 36 columns]

# %%
scopus_results.to_csv("ScopusArticles.csv")

# %% [markdown]
# # Semantic Scholar

# %%
# First, import the client from semanticscholar module
from semanticscholar import SemanticScholar

# You'll need an instance of the client to request data from the API
sch = SemanticScholar()

# %%
q_semanticScholar = '"( "graph" OR "community detection" OR "group" OR "cluster") AND ( "relevance" OR "redundancy" ) AND ( "feature selection" OR "dimensionality reduction" ) AND ( "biological" OR "Gene expression" OR "omics" )'

response = sch.search_paper(query=q_semanticScholar, bulk=True, sort='publicationDate:desc')

len(response)
# Out:
# 0

# %%
all_results = []
i = 1
for item in response:
    all_results.append(item)
#    print(i)
    i += 1

len(all_results)
# Out:
# 0

# %% [markdown]
# # IEEE Xplore

# %%
from xploreapi.xploreapi import XPLORE

# %%
query = XPLORE('juvdzkf86jj5k6qf5hx8k5mp')
query.searchField('boolean_text', '"feature selection" AND "graph"')
query.maximumResults(2000)
query.resultsSorting('publication_year','asc')
data = query.callAPI()

# %%
data
# Out:
# '<h1>Developer Inactive</h1>'
